# %%
path_to_zip_file = "DC_Properties.csv.zip"
directory_to_extract_to = ""

import zipfile
zip_ref = zipfile.ZipFile(path_to_zip_file,'r')
zip_ref.extractall(directory_to_extract_to)
zip_ref.close()

# %%
import pandas as pd

df = pd.read_csv("DC_Properties.csv")

df
# Out:
# C:\Users\Michel-Ange\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# ...

# %%
# Show duplicates
dupe = df.loc[df.duplicated()]

dupe
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
# How many missing values do we have ?
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
# Average Housing Price
df['PRICE'].mean()
# Out:
# 931351.5949336156

# %%
# Min Housing Price
df['PRICE'].min()
# Out:
# 1.0

# %%
# The more frequent price (mode)
df['PRICE'].mode()
# Out:
# 0    350000.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
# Average Price and Number of rooms per condition

df[['PRICE','ROOMS']].groupby(df['CNDTN']).mean()
# Out:
#                   PRICE     ROOMS
# CNDTN
# Average    3.755836e+05  7.121648
# Default    8.518500e+06  0.315789
# Excellent  1.247995e+06  8.652466
# Fair       4.093604e+05  7.260606
# Good       6.551493e+05  7.586474
# Poor       4.742626e+05  6.977143
# Very Good  9.455850e+05  8.143419

# %%
# Average Price and quantity of rooms per source

df[['PRICE','ROOMS']].groupby(df['SOURCE']).mean()
# Out:
#                     PRICE     ROOMS
# SOURCE
# Condominium  1.436073e+06  3.748857
# Residential  5.799119e+05  7.382329

# %%
pd.pivot_table(df,index=['ROOMS','CNDTN','SOURCE'],values=['PRICE'],aggfunc='mean')
# Out:
#                                     PRICE
# ROOMS CNDTN     SOURCE
# 0     Average   Residential  2.493296e+05
#       Default   Residential  1.119167e+07
#       Fair      Residential  9.893333e+05
#       Good      Residential  2.950000e+05
#       Poor      Residential  2.968510e+06
#       Very Good Residential           NaN
# 1     Average   Residential           NaN
#       Default   Residential           NaN
#       Fair      Residential  5.613000e+04
#       Good      Residential           NaN
# 2     Average   Residential  2.339993e+05
#       Fair      Residential           NaN
#       Good      Residential  1.055500e+06
#       Poor      Residential           NaN
# 3     Average   Residential  2.393207e+05
#       Excellent Residential           NaN
#       Fair      Residential  5.674600e+05
#       Good      Residential  5.109397e+05
#       Very Good Residential  5.290000e+05
# 4     Average   Residential  2.781585e+05
#       Excellent Residential  6.800000e+05
# ...
